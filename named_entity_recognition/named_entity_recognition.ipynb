# %% [markdown]
# # Named Entity Recognition
#
# Named Entity Recognition in NLP focuses on identifying and catergorizing important information known as entities in text. These entities can be names of people, places, it helps transform unstructured text into structured information.
