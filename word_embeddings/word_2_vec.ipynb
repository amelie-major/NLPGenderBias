# %% [markdown]
# # Word Embedding using Word2Vec
#
# Word2Vec is a word embedding technique in natural language processing that allows words to be represented as vectors in continuous vector space and they can capture the semantic relationships between words.
#
# It uses two architectures:
#
# * Continous Bag of Words (CBOW) - this model predicts the current word given context words. The input layer contains the context words and the output layer contains the current word. The hidden layer contains the dimensions we want to represent the current word present at the outer layer.
#
# * Skip Gram - this predicts the surrounding context words within specific window given current word. The input layer contains the current word and the output layer the context words. The hidden layer contains the number of dimensions in which we want to represent current word present at the input layer.
#
# ## Importing modules
# We will import Word2Vec from `gensim` and build the word vector model and then `nltk.tokenize` helps splitting text into sentences and words.

# %%
from gensim.models import Word2Vec
import gensim
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ameliemajor/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Loading and cleaning the dataset
#
# We will then load and clean the dataset from a zip file, clean it by removing newline characters and prepare it for tokenization

# %%
import zipfile
import os

content = open("../data/cleaned_tweets.txt", 'r').read()
cleaned_text = content.replace("\n", " ")
print("File loaded")
# Out:
# File loaded

# %% [markdown]
# ## Text Tokenisation
#
# We will tokenize the cleaned text into sentecne and words. We will append these tokenized words into lists where each list is a sublist

# %%
data = []
for i in sent_tokenize(cleaned_text):
    temp = []

    # tokenize the sentence into words
    for j in word_tokenize(i):
        temp.append(j.lower())

    data.append(temp)

# %% [markdown]
# ## Build Word2Vec Models
#
# 1. Using CBOW Model

# %%
model1 = gensim.models.Word2Vec(data, min_count=1,
                                vector_size=100, window=5)
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %% [markdown]
# 2. Using Skip-Gram Model

# %%
model2 = gensim.models.Word2Vec(data, min_count=1, vector_size=100,
                                window=5, sg=1)
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %% [markdown]
# ## Evaluating Word Similarities

# %%
print("Cosine similarity between 'she' " +
      "and 'daughter' - CBOW : ",
      model1.wv.similarity('she', 'mother'))

print("Cosine similarity between 'he' " +
      "and 'son' - CBOW : ",
      model1.wv.similarity('he', 'mother'))
# Out:
# Cosine similarity between 'she' and 'daughter' - CBOW :  0.38561618
# Cosine similarity between 'he' and 'son' - CBOW :  0.35036123
