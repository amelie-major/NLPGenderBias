# %% [markdown]
# # Using Natural Language Processing to explore Gender Biases in the British Political Media
# * Explain the context and introduce the dataset
# * Highlight primary research questions
# * Write an overview of the pipeline
#
# **RQ1**: How can use natural language processing to quantify gender representation bias in British political news?
#
# **RQ2**: How can use natural language processing to quantify gender sentiment bias in British political news?
#
# **RQ3**: How can use natural language processing to quantify gender framing bias in British political news?
#
# **RQ4**: What benchmarks metrics and other qualitative approaches can we use to evaluate our findings against?

# %% [markdown]
# # 1. Data Preprocessing
# ## Load the dataset into a dataframe
# Unzip the zip file and load the `.csv` into a CUDF

# %% [markdown]
# ## Create Dataframe of Articles with Political label
# Here we will evaluate the size of the dataframe we are working with

# %% [markdown]
# ## Extend Corpus with Opinion Data

# %% [markdown]
# # 2. Statistical Analysis

# %% [markdown]
# # 3. Named Entity Recognition for Gender
#
# When evaluating the dataset

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# # Topic Modelling
#
# This answers questions about framing bias? We want to know how different topics between di
